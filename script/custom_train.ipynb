# %% [markdown]
# ### Downloading the Dataset

# %%
# !pip install kaggle
# Out:
# ...
#      |████████████████████████████████| 84 kB 1.2 MB/s eta 0:00:01
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.6-py3-none-any.whl size=111964 sha256=ab56683bc67c695d7727f00d2eb2027467573b9c1b6febd9284f8e892ef2525b
#   Stored in directory: /home/ncrl/.cache/pip/wheels/46/aa/c3/b3e421522fb5acdd7c366a05c5fc80787615bdeed207e7f79b
# Successfully built kaggle
# ...

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d snehilsanyal/construction-site-safety-image-dataset-roboflow
# Out:
# ...
# 100%|████████████████████████████████████████| 206M/206M [00:20<00:00, 10.3MB/s]
# 100%|████████████████████████████████████████| 206M/206M [00:20<00:00, 10.5MB/s]

# %%
# !unzip construction-site-safety-image-dataset-roboflow.zip
# Out:
# Archive:  construction-site-safety-image-dataset-roboflow.zip
#   inflating: css-data/README.dataset.txt
#   inflating: css-data/README.roboflow.txt
#   inflating: css-data/test/images/-4405-_png_jpg.rf.82b5c10b2acd1cfaa24259ada8e599fe.jpg
#   inflating: css-data/test/images/000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg
#   inflating: css-data/test/images/002551_jpg.rf.ce4b9f934161faa72c80dc6898d37b2d.jpg
#   inflating: css-data/test/images/003357_jpg.rf.9867f91e88089bb68dc95947d5116d14.jpg
#   inflating: css-data/test/images/004063_jpg.rf.1b7cdc4035bcb24ef69b8798b444053e.jpg
#   inflating: css-data/test/images/004763_jpg.rf.46484e6ca73caeaa9de45822cf1085a9.jpg
#   inflating: css-data/test/images/006463_jpg.rf.02f19082420ecc5537b9d59abbe6050c.jpg
#   inflating: css-data/test/images/006672_jpg.rf.87d5978c486feb53177408cf00a0d87f.jpg
#   inflating: css-data/test/images/0_jpg.rf.2ff49f74309118f169e07aa12564df87.jpg
# ...

# %% [markdown]
# ### Install Ultralytics

# %%
# !pip install ultralytics

# %%
import os
import cv2
import glob
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from ultralytics import YOLO

import warnings
warnings.filterwarnings('ignore')
np.random.seed(12345)
# Out:
# /home/ncrl/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
cwd = os.getcwd()
print("Current working directory:", cwd)
# Out:
# Current working directory: /home/ncrl/ncrl/yolo_ws/src/yolov8/sample

# %%
dataDir = '/home/ncrl/ncrl/yolo_ws/src/yolov8/sample/css-data/'
workingDir = '/home/ncrl/ncrl/yolo_ws/src/yolov8/sample/'

# %%
num_classes = 10
classes = ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'machinery', 'vehicle']

# %%
file_dict = {
    'train': os.path.join(dataDir, 'train'),
    'val': os.path.join(dataDir, 'valid'),
    'test': os.path.join(dataDir, 'test'),
    'nc': num_classes,
    'names': classes
}

with open(os.path.join(workingDir, 'data.yaml'), 'w+') as f:
  yaml.dump(file_dict, f)

# %%
class_idx = {str(i):classes[i] for i in range(num_classes)}
class_stat = {}
data_len = {}

for mode in ['train', 'valid', 'test']:
  class_count = {classes[i]:0 for i in range(num_classes)}
  path = os.path.join(dataDir, mode, 'labels')
  for file in os.listdir(path):
    
    with open(os.path.join(path, file)) as f:
      lines = f.readlines()
      for cls in set([line[0] for line in lines]):
        class_count[class_idx[cls]] += 1
  data_len[mode] = len(os.listdir(path))
  class_stat[mode] = class_count

# %%
fig, ax = plt.subplots(1,3, figsize=(15, 5), sharey=True)

for i, model in enumerate(['train', 'valid', 'test']):
  sns.barplot(pd.DataFrame({mode:class_stat[mode]}).T/data_len[mode]*100, ax=ax[i])
  ax[i].set_title(mode)
  ax[i].tick_params(rotation=90)
  ax[i].set_ylabel('Percenatage of classes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17905/14657556.py in <module>
#       2
#       3 for i, model in enumerate(['train', 'valid', 'test']):
# ----> 4   sns.barplot(pd.DataFrame({mode:class_stat[mode]}).T/data_len[mode]*100, ax=ax[i])
#       5   ax[i].set_title(mode)
#       6   ax[i].tick_params(rotation=90)
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...

# %%
for mode in ['train', 'valid', 'test']:
  print(f' \nImage sizes in {mode} set:\n')
  image_size = 0
  for file in glob.glob(os.path.join(dataDir, mode, 'images', '*')):
    image = Image.open(file)
    if image.size != image_size:
      print(image.size)
      image_size = image.size
# Out:
#
# Image sizes in train set:
#
# (640, 640)
#
# Image sizes in valid set:
#
# (640, 640)
#
# Image sizes in test set:
#
# (640, 640)

# %%
for mode in ['train', 'valid', 'test']:
  files = glob.glob(os.path.join(dataDir, mode, 'images','*'))
  print(f'{mode} set size: {len(files)}\n')
# Out:
# train set size: 2605
#
# valid set size: 114
#
# test set size: 82

# %% [markdown]
# ### Downwloading the YOLOv8 Model

# %%
model = YOLO('yolov8n.pt')

# %% [markdown]
# ### Train the Model

# %%
model.train(data=os.path.join(workingDir, 'data.yaml'),
            task = 'detect',
            imgsz = 640,
            epochs = 10,
            batch = 32,
            mode = 'train',
            name = 'yolov8_trained_model')
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.9.7 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7960MiB)
# ...

# %% [markdown]
# ### Getting the best Model

# %%
model = YOLO('/home/ncrl/ncrl/yolo_ws/src/yolov8/sample/runs/detect/yolov8_trained_model/weights/best.pt')

# %% [markdown]
# ### Predictions

# %%
#results = model.predict(source=os.path.join(dataDir, 'test', 'images'), save = True)
results = model.predict(source='/home/ncrl/ncrl/yolo_ws/src/yolov8/sample/source_files/source_files/schupan_japan1web.jpg', save = True)
# Out:
# image 1/1 /home/ncrl/ncrl/yolo_ws/src/yolov8/sample/source_files/source_files/schupan_japan1web.jpg: 384x640 5 Hardhats, 1 NO-Hardhat, 6 NO-Masks, 1 NO-Safety Vest, 6 Persons, 5 Safety Vests, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
boxes = results[0].boxes.xywh.cpu()
track_ids = results[0].boxes

x, y, w, h = boxes[0]
#print('x:', x, 'y:', y, 'w:', w, 'h:', h)
print(track_ids)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 7., 5., 5., 5., 0., 7., 0., 0., 7., 7., 5., 5., 7., 5., 0., 4., 3., 3., 3., 3., 3., 3., 2.], device='cuda:0')
# conf: tensor([0.9254, 0.9112, 0.8935, 0.8752, 0.8634, 0.8584, 0.8519, 0.8375, 0.8336, 0.8324, 0.8270, 0.8161, 0.8095, 0.7998, 0.7886, 0.7732, 0.6279, 0.5872, 0.5678, 0.5270, 0.4766, 0.3697, 0.3306, 0.2895], device='cuda:0')
# data: tensor([[4.8870e+02, 1.3605e+02, 5.4767e+02, 1.7983e+02, 9.2540e-01, 0.0000e+00],
#         [3.8536e+02, 2.1476e+02, 4.8299e+02, 3.8632e+02, 9.1115e-01, 7.0000e+00],
#         [5.4607e+02, 9.1524e+01, 7.0753e+02, 4.1329e+02, 8.9352e-01, 5.0000e+00],
#         [5.1306e+01, 1.1277e+02, 2.0450e+02, 4.1400e+02, 8.7518e-01, 5.0000e+00],
#         [1.5975e+02, 1.2646e+02, 3.0634e+02, 4.1400e+02, 8.6339e-01, 5.0000e+00],
#         [5.8345e+02, 9.1520e+01, 6.4802e+02, 1.3752e+02, 8.5838e-01, 0.0000e+00],
# ...

# %%
pred = glob.glob('/home/ncrl/ncrl/yolo_ws/src/yolov8/sample/runs/detect/predict/*') 
n = 5  
num_rows = len(pred) // n

fig, axs = plt.subplots(num_rows, n, figsize=(25, 5*num_rows))
for i in range(num_rows):
    for j in range(n):
        idx = i*n + j  # Calculate the index of the image to display
        if idx < len(pred):
            image = Image.open(pred[idx])
            axs[i, j].imshow(image)
            axs[i, j].grid(False)
            axs[i, j].axis('off')
plt.show()
